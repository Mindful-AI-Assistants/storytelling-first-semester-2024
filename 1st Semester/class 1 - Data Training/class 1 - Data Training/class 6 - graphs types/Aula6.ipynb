# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Gráfico de linha

# %% [markdown]
# Line plot simples

# %%
x  = np.array([1,2,3,4,5])
y = 2*x

plt.plot(x,y)

# %%
x  = np.linspace(-2,10,50)
y = -(x-2.5)**2 # dado artificial

plt.plot(x,y)
plt.arrow(2,-10,0.5,8.5, width=-0.1, head_width=1)
plt.text(2.5,0.5, "Ponto crítico")
# Out:
# Text(2.5, 0.5, 'Ponto crítico')

# %%
x  = np.linspace(-2,10,50)
y1 = -(x-2.5)**2 # dado artificial
y2 = -(x-2.5)**3 # dado artificial

plt.plot(x,y1,x,y2)

# %% [markdown]
# ## Gráfico de barras

# %%
x= np.array([1,2,3,4,5])
y1 = x+2

plt.bar(x,y1)
# Out:
# <BarContainer object of 5 artists>

# %%
import seaborn as sns

df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='origin', y='mpg', data=df)
plt.title('MPG médio por origem')
plt.show()

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
set(df['origin'])
# Out:
# {'europe', 'japan', 'usa'}

# %%
df['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
# Gráfico de barras
plt.bar(df['origin'], df['mpg'])
# Out:
# <BarContainer object of 398 artists>

# %%
# Exemplo do próprop matplotlib
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/

species = (
    "Adelie",
    "Chinstrap",
    "Gentoo",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, weight_count in weight_counts.items():
    p = ax.bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

ax.set_title("Number of penguins with above average body mass")
ax.legend(loc="upper right")

plt.show()

# %% [markdown]
# ## Gráfico de Pizza

# %%
# Gráfico de Pizza para mostrar a distribuição de carros por origem
plt.figure(figsize=(10, 6))
df['origin'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribuição de carros por origem')
plt.show()

# %% [markdown]
# # Gráfico de área

# %%
plt.figure(figsize=(10, 6))
df_grouped = df.groupby('model_year')['mpg'].mean()
df_grouped.plot(kind='area', color="skyblue", alpha=0.4)
plt.title('MPG médio ao longo dos anos')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados de exemplo
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Gráfico de Combinações
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Linha')
plt.scatter(x, y, color='red', label='Dispersão')
plt.title('Gráfico de Combinações')
plt.legend()
plt.show()

# %% [markdown]
# ## Gráfico de dispersão

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['weight'], df['mpg'])
plt.title('Peso vs MPG')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='weight', y='mpg', hue='origin', data=df)
plt.title('MPG vs Peso por origem')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='weight', y='mpg', hue='origin', size='cylinders', data=df)
plt.title('MPG vs Peso por origem e cilindros')
plt.show()

# %% [markdown]
# ---

# %%
# Gráfico de Linhas
plt.figure(figsize=(10, 6))
plt.plot(df['model_year'], df['mpg'])
plt.title('MPG ao longo dos anos')
plt.show()

# %%
import matplotlib.pyplot as plt

# Carregando os dados
df = sns.load_dataset('mpg')

# Definindo o tamanho da figura
plt.figure(figsize=(10, 6))

# Criando um gráfico de linhas para cada origem
for origin in df['origin'].unique():
    subset = df[df['origin'] == origin]
    plt.plot(subset['model_year'], subset['mpg'], label=origin)

# Adicionando um título e uma legenda
plt.title('MPG ao longo dos anos por origem')
plt.legend()

# Mostrando o gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='model_year', y='mpg', hue='origin', data=df)
plt.title('MPG ao longo dos anos por origem')
plt.show()

# %%
# Variante do gráfico de barras
plt.figure(figsize=(10, 6))
sns.boxplot(x='origin', y='mpg', hue='cylinders', data=df)
plt.title('Distribuição de MPG por origem e cilindros')
plt.show()
