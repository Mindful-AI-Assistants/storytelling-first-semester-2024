# %%
# Dependências
from sympy import symbols, Function
import matplotlib.pyplot as plt
import numpy as np

# %%
# Definindo a variável simbólica
x = symbols('x')

# Definindo funções simbólicas
f = Function('f')(x)
g = Function('g')(x)

# Definindo algumas funções simples
f = x**2 + 3*x + 2
g = 2*x + 1

xx = np.linspace(0,30, 200)

y1 = []
y2 = []

for i in range(200):
  y1.append( float(f.subs(x, xx[i])) ) # saida de texto, tem que converter para float
  y2.append( float(g.subs(x, xx[i])) ) # saida de texto, tem que converter para float

# %%
import matplotlib.font_manager as fm

# Fonte importada de um arquivo
path = "fonte/Georgia.ttf"
prop = fm.FontProperties(fname = path)

plt.plot(xx, y1, color ="#3F77B4")
plt.plot(xx, y2, color = "#e4c023")

plt.xlabel('Tempo (dias)', fontproperties=prop, size = 12) # exemplo
plt.ylabel('Custo (R$)', fontproperties=prop, size = 12)
plt.title('Plano de ação', fontproperties=prop, size= 18)
plt.xticks(fontproperties=prop)
plt.yticks(fontproperties=prop)

plt.legend(['Estratégia 1', 'Estratégia 2'], prop=prop)

plt.show()
