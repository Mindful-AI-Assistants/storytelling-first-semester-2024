# %%
#Mudar o PATH da sua máquina
countryData = pd.read_csv("/content/countryData.csv").drop("Unnamed: 0", axis = 1)
countryData
# Out:
#     country  year  Access to electricity  Electricity production(coal)  \
# 0       BGD  2011              59.599998                      1.873032
# 1       BGD  2012              66.155571                      1.927433
# 2       BGD  2013              61.500000                      2.306099
# 3       BGD  2014              62.400002                      1.969738
# 4       BGD  2015              74.903740                      1.689516
# ..      ...   ...                    ...                           ...
# 103     USA  2017             100.000000                           NaN
# 104     USA  2018             100.000000                           NaN
# 105     USA  2019             100.000000                           NaN
# 106     USA  2020             100.000000                           NaN
# 107     USA  2021                    NaN                           NaN
#
#      Energy use per capita  co2 emissions  Inflation    Exports  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# !pip install pandas

# %%
## 1- Gráfico de PIB per capta - Fundo Preto

# Paleta de cores fortes (você pode escolher outras combinações)
palette = ["#F94144", "#F3722C", "#F8961E", "#90BE6D", "#43AA8B", "#4D5360"]

# Criar a figura e o eixo com fundo preto
plt.figure(figsize=(10, 6))
ax = plt.axes(facecolor='black')  # define o fundo do gráfico como preto.

# Criar o gráfico de linhas com Seaborn
sns.lineplot(x="year", y="GDP Per Capita (USD)", hue="country", data=countryData,
             palette=palette, linewidth=2.5, ax=ax)  # Aumentar a espessura das linhas

 # Personalizar o gráfico
ax.set_title("Evolução do GDP per capita por País", fontsize=20, color='Black')  # Título em Prero
ax.set_xlabel("Ano", fontsize=14, color='black')  # Rótulos em Preto
ax.set_ylabel("GDP per capita (USD)", fontsize=13, color='Black')
ax.tick_params(axis='x', colors='gray')  # Marcadores do eixo x em cinza
ax.tick_params(axis='y', colors='gray')  # Marcadores do eixo y em gray
ax.grid(True, color='white', alpha=0.4)  # Grade em cinza branco com transparencia

# Ajustar a legenda (opcional)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, facecolor='black',
           edgecolor='None', labelcolor='white')  # Legenda com fundo preto e texto branco

plt.show()


## 2-Evolução temporal do acesso a eletricidade por país

# Paleta de cores fortes (você pode escolher outras combinações)
palette = ["#F94144", "#F3722C", "#F8961E", "#90BE6D", "#43AA8B", "#4D5360"]

# Criar a figura e o eixo com fundo preto
plt.figure(figsize=(10, 6))
ax = plt.axes(facecolor='black')  # define o fundo do gráfico como preto.

# Criar o gráfico de linhas com Seaborn
sns.lineplot(x="year", y="Access to electricity", hue="country", data=countryData,
             palette=palette, linewidth=2.5, ax=ax)
# Out:
# <ipython-input-6-acc761cbf298>:11: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(x="year", y="GDP Per Capita (USD)", hue="country", data=countryData,
# <ipython-input-6-acc761cbf298>:39: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(x="year", y="Access to electricity", hue="country", data=countryData,
# <Axes: xlabel='year', ylabel='Access to electricity'>
